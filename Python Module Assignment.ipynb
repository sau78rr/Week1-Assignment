# %% [markdown]
# # Numpy Implementation

# %%
import numpy as np
# Create a 2D Numpy array of size 1x3 with elements of your choice
arr1=np.array([[1,2,3]])


# Create a Numpy array of length 50 with zeroes as its elements
arr2=np.zeros(50)


#Create a Numpy array of length 3x2 with elements of your choice
arr3=np.array([[1,2],[3,4],[5,6]])


#Multiply arr1 and arr3 using Numpy functions
arr4=np.matmul(arr1,arr3)

#Change 5th element of arr2 to a different number
#Your code here
arr2[4]=12

if np.shape(arr4)==(1,2) and arr2[4]!=0:
  print("Passed")
else:
  print("Fail")
# Out:
# Passed

# %%
import numpy as np
#Task: Perform the dot product of I and 9I+1 using numpy, here I is referred to as an 3x3 Identity matrix.
I=np.identity(3)
dotproduct=np.dot(I,9*I+1)
print(dotproduct)
# Out:
# [[10.  1.  1.]
#  [ 1. 10.  1.]
#  [ 1.  1. 10.]]

# %% [markdown]
# # Pandas Implementation

# %%
import pandas as pd

## Create a DataFrame from a dictionary
data = {
    'Name': ['Ramesh', 'Mahesh', 'Suresh'],
    'Age': [25, 30, 35],
    'City': ['Bangalore', 'Mumbai', 'Delhi']
}
#Your code here
df=pd.DataFrame(data)

#Display the first 2 rows of the data frame
#Your code here
print(df.head(2))
#Print the age column
#Your code here
print(df['Age'])
#Filter rows where age is greater than 26
#Your code here
Rows=df[df['Age']>26]

#Add a new column 'Country' with the value 'India' for all rows
#Your code here
df['Country']='India'



data1 = {
    'Name': ['Ramesh', 'Mahesh', 'Suresh'],
    'Age': [25, None, 35],
    'City': ['Bangalore', 'Mumbai', 'Delhi']
}

df2= pd.DataFrame(data1)

# Fill missing values in the 'Age' column with the mean age
#Your code here

mean_age = df2['Age'].mean()
df2['Age'].fillna(mean_age, inplace=True)
# Out:
#      Name  Age       City
# 0  Ramesh   25  Bangalore
# 1  Mahesh   30     Mumbai
# 0    25
# 1    30
# 2    35
# Name: Age, dtype: int64
#      Name   Age       City
# 0  Ramesh  25.0  Bangalore
# 1  Mahesh  30.0     Mumbai
# 2  Suresh  35.0      Delhi

# %% [markdown]
# # Matplotlib Implementation

# %%
import matplotlib.pyplot as plt
import numpy as np
#numpy module. Fill your code



xpoints=np.array([1,2,3,4])
ypoints=np.array([2,4,6,8])

#Plot these points without drawing a line
#Your code here
plt.figure(figsize=(4,4))
plt.scatter(xpoints,ypoints)

#Plotting with marker: Plot these points with a marker(Star marker)
#Your code here
plt.figure(figsize=(5,5))
plt.scatter(xpoints,ypoints,marker='*')
#Using fmt format, add circular marker,red color and Dashed line
#Your code here

plt.figure(figsize=(5,5))
plt.plot(xpoints,ypoints,'ro--', markersize=8,color='red')
#Add xlabel,ylabel and title for the plot.
#Your code here
plt.xlabel("xpoints")
plt.ylabel("ypoints")
plt.title("plot of x Vs y")
#Create a scatter plot for xpoints and ypoints
#Your code here
plt.figure(figsize=(5,5))
colors=['Blue','Green','Red','Yellow']
for i in range(4):
    plt.scatter(xpoints[i],ypoints[i],color=colors[i])
#Set color to the scatter plot. Blue,Green,Red and yellow color for each point respectively
# Out:
# C:\Users\saura\AppData\Local\Temp\ipykernel_30800\4001672628.py:23: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "ro--" (-> color='r'). The keyword argument will take precedence.
#   plt.plot(xpoints,ypoints,'ro--', markersize=8,color='red')

# %% [markdown]
# # Miscellaneous Modules Implementation

# %%
import random
import numpy as np

#Set the seed of random to 20
#Your code here
random.seed(20)
arr1=np.array([1,24,31,45,73,81,94,25])

#Using the random module pick 4 different random numbers from arr1 and return their sum.
#Your code here
random_numbers = np.random.choice(arr1, size=4, replace=False)
summ=random_numbers.sum()
print(random_numbers," their sum is: ",summ)
# Out:
# [24 31 81  1]  their sum is:  137
